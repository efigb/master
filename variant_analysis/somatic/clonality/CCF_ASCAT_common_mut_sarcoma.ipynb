# %% [markdown]
# # ASCAT_CCF calculation in sarcoma sample

# %%
# Needed basic packages
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from tqdm import tqdm_notebook
from matplotlib_venn import venn3
import time

# %%
from tqdm.notebook import tqdm_notebook
tqdm_notebook.pandas()

# %%
# Import filtered mutation files 
common_mut_df = pd.read_csv('/workspace/projects/sjd_melos/MAFs_tables/Sar_List_common_mutations_callers.tsv.gz', sep="\t", header=0)

# Import purity value

ascat_purity_df = pd.read_csv('/workspace/projects/sjd_melos/var_call_output/sarek_results/variant_calling/ascat/AX4967_vs_AB9766/AX4967_vs_AB9766.purityploidy.txt', sep="\t", header=0)
ascat_cnv_df = pd.read_csv('/workspace/projects/sjd_melos/var_call_output/sarek_results/variant_calling/ascat/AX4967_vs_AB9766/AX4967_vs_AB9766.cnvs.txt', sep="\t", header=0)
ascat_segm_df = pd.read_csv('/workspace/projects/sjd_melos/var_call_output/sarek_results/variant_calling/ascat/AX4967_vs_AB9766/AX4967_vs_AB9766.segments.txt', sep="\t", header=0)

# %%
common_mut_df.head()
# Out:
#   CHROM      POS ID REF ALT QUAL FILTER  \
# 0  chr1   104188  .   C   A    .   PASS
# 1  chr1   843320  .   G   A    .   PASS
# 2  chr1  1014876  .   G   T    .   PASS
# 3  chr1  1118520  .   C   T    .   PASS
# 4  chr1  1136548  .   G   T    .   PASS
#
#                                                 INFO  \
# 0  AS_FilterStatus=SITE;AS_SB_TABLE=36,157|24,22;...
# 1  AS_FilterStatus=SITE;AS_SB_TABLE=105,87|38,31;...
# 2  AS_FilterStatus=SITE;AS_SB_TABLE=162,109|4,2;D...
# 3  AS_FilterStatus=SITE;AS_SB_TABLE=120,130|19,26...
# 4  AS_FilterStatus=SITE;AS_SB_TABLE=86,92|45,45;D...
#
#                                     FORMAT  \
# 0  GT:AD:AF:DP:F1R2:F2R1:FAD:PGT:PID:PS:SB
# 1             GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 2             GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 3             GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 4             GT:AD:AF:DP:F1R2:F2R1:FAD:SB
#
#                                               NORMAL  ... n_DP  t_alt_reads  \
# 0  0|0:124,0:7.128e-03:124:33,0:29,0:125,0:0|1:10...  ...  124           46
# 1  0/0:126,0:7.857e-03:126:58,0:63,0:125,0:67,59,0,0  ...  126           69
# 2  0/0:141,0:7.025e-03:141:64,0:69,0:139,0:85,56,0,0  ...  141            6
# 3  0/0:153,0:6.470e-03:153:62,0:83,0:152,0:78,75,0,0  ...  153           45
# 4  0/0:123,0:8.107e-03:123:60,0:59,0:121,0:57,66,0,0  ...  123           90
#
#    n_alt_reads  t_ref_reads  n_ref_reads       VAF  mut_type  Caller_intersec  \
# 0            0           69          124  0.400000       SNV   Mutect_Strelka
# 1            0           66          126  0.511111       SNV   Mutect_Strelka
# 2            0          130          141  0.044118       SNV   Mutect_Strelka
# 3            0           97          153  0.316901       SNV   Mutect_Strelka
# 4            0           55          123  0.620690       SNV   Mutect_Strelka
#
#     SAMPLE               mut
# 0  sarcoma   chr1_104188_C_A
# 1  sarcoma   chr1_843320_G_A
# 2  sarcoma  chr1_1014876_G_T
# 3  sarcoma  chr1_1118520_C_T
# 4  sarcoma  chr1_1136548_G_T
#
# [5 rows x 24 columns]

# %%
# Extract purity value from table, note that this value is the Aberrant Cell Fraction
purity = ascat_purity_df['AberrantCellFraction']
purity
# Out:
# 0    0.6
# Name: AberrantCellFraction, dtype: float64

# %% [markdown]
# ## 1/ Processing ASCAT files (ascat_cnvs vs ascat_segments)

# %% [markdown]
# ### a. ASCAT CNV FILE

# %%
ascat_cnv_df.head()
# Out:
#   chr  startpos    endpos  nMajor  nMinor
# 0   1    809641  14842839       2       0
# 1   1  14844137  15712384       4       0
# 2   1  15715111  21695683       2       0
# 3   1  21707894  21727934       2       1
# 4   1  21729424  26321837       2       2

# %%
# Calculate copy number (CN) from cnv files and add it as new column 
ascat_cnv_df[['nMajor', 'nMinor']] = ascat_cnv_df[['nMajor', 'nMinor']].astype(int) # convert so it is operable, not string
ascat_cnv_df['CN'] = ascat_cnv_df['nMajor'] + ascat_cnv_df['nMinor'] # CN is the sum of nMajor and nMinor alleles
ascat_cnv_df.head()
# Out:
#   chr  startpos    endpos  nMajor  nMinor  CN
# 0   1    809641  14842839       2       0   2
# 1   1  14844137  15712384       4       0   4
# 2   1  15715111  21695683       2       0   2
# 3   1  21707894  21727934       2       1   3
# 4   1  21729424  26321837       2       2   4

# %%
# Add in chr column "chr" to homogenize nomenclature as common_mut_df 
ascat_cnv_df['chr'] = ascat_cnv_df['chr'].apply(lambda x: 'chr'+str(x))
ascat_cnv_df.head()
# Out:
#     chr  startpos    endpos  nMajor  nMinor  CN
# 0  chr1    809641  14842839       2       0   2
# 1  chr1  14844137  15712384       4       0   4
# 2  chr1  15715111  21695683       2       0   2
# 3  chr1  21707894  21727934       2       1   3
# 4  chr1  21729424  26321837       2       2   4

# %%
# Rename columns and drop unnecessary columns
ascat_cnv_df = ascat_cnv_df.rename(columns={'chr':'chrom','startpos':'start', 'endpos':'end'})
ascat_cnv_df = ascat_cnv_df.drop(columns=['nMajor','nMinor'])
ascat_cnv_df.head()
# Out:
#   chrom     start       end  CN
# 0  chr1    809641  14842839   2
# 1  chr1  14844137  15712384   4
# 2  chr1  15715111  21695683   2
# 3  chr1  21707894  21727934   3
# 4  chr1  21729424  26321837   4

# %% [markdown]
# ### b. ASCAT SEGM FILE

# %%
ascat_segm_df.head()
# Out:
#                     sample chr  startpos    endpos  nMajor  nMinor
# 0  AX4967_vs_AB9766.tumour   1    809641  14842839       2       0
# 1  AX4967_vs_AB9766.tumour   1  14844137  15712384       4       0
# 2  AX4967_vs_AB9766.tumour   1  15715111  21695683       2       0
# 3  AX4967_vs_AB9766.tumour   1  21707894  21727934       2       1
# 4  AX4967_vs_AB9766.tumour   1  21729424  26321837       2       2

# %%
# Calculate copy number (CN) from cnv files and add it as new column 
ascat_segm_df[['nMajor', 'nMinor']] = ascat_segm_df[['nMajor', 'nMinor']].astype(int) # convert so it is operable, not string
ascat_segm_df['CN'] = ascat_segm_df['nMajor'] + ascat_segm_df['nMinor'] # CN is the sum of nMajor and nMinor alleles
ascat_segm_df.head()
# Out:
#                     sample chr  startpos    endpos  nMajor  nMinor  CN
# 0  AX4967_vs_AB9766.tumour   1    809641  14842839       2       0   2
# 1  AX4967_vs_AB9766.tumour   1  14844137  15712384       4       0   4
# 2  AX4967_vs_AB9766.tumour   1  15715111  21695683       2       0   2
# 3  AX4967_vs_AB9766.tumour   1  21707894  21727934       2       1   3
# 4  AX4967_vs_AB9766.tumour   1  21729424  26321837       2       2   4

# %%
ascat_segm_df['chr'] = ascat_segm_df['chr'].progress_apply(lambda x: 'chr'+str(x))
# ascat_segm_df.head()
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
# Rename columns and drop unnecessary columns
ascat_segm_df = ascat_segm_df.rename(columns={'chr':'chrom','startpos':'start', 'endpos':'end'})
ascat_segm_df = ascat_segm_df.drop(columns=['sample','nMajor','nMinor'])
ascat_segm_df.head()
# Out:
#   chrom     start       end  CN
# 0  chr1    809641  14842839   2
# 1  chr1  14844137  15712384   4
# 2  chr1  15715111  21695683   2
# 3  chr1  21707894  21727934   3
# 4  chr1  21729424  26321837   4

# %% [markdown]
# ## 2/ Add CN to common mutations df

# %% [markdown]
# ### 2.1 Try to obtain CN with a function

# %%
# def get_cn (row):
#     mut = row['CHROM']
#     startpos = ascat_cnv_df['startpos']
#     endpos = ascat_cnv_df['endpos']
#     cnv = ascat_cnv_df['CN']
#     for row in common_mut_df.iterrows():
#         if mut >= startpos & mut <= endpos:
#             CNV = row(cnv)
#             break
#     return CNV

# common_mut_df['CN'] = common_mut_df.progress_apply(lambda row: get_cn(row),axis=1)

def get_cn(row, ascat_cnv_df):
    mut = int(row['CHROM'])  # Convert CHROM to integer
    for index, ascat_row in ascat_cnv_df.iterrows():
        startpos = int(ascat_row['startpos'])  # Convert startpos to integer
        endpos = int(ascat_row['endpos'])  # Convert endpos to integer
        cnv = ascat_row['CN']
        if mut >= startpos and mut <= endpos:
            return cnv
    return None

common_mut_df['CN'] = common_mut_df.apply(lambda row: get_cn(row, ascat_cnv_df), axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 24
#      21             return cnv
#      22     return None
# ---> 24 common_mut_df['CN'] = common_mut_df.apply(lambda row: get_cn(row, ascat_cn_df), axis=1)
#
# File ~/miniconda3/envs/melos/lib/python3.11/site-packages/pandas/core/frame.py:10037, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10025 from pandas.core.apply import frame_apply
#   10027 op = frame_apply(
#   10028     self,
#   10029     func=func,
#    (...)
#   10035     kwargs=kwargs,
#   10036 )
# > 10037 return op.apply().__finalize__(self, method="apply")
#
# File ~/miniconda3/envs/melos/lib/python3.11/site-packages/pandas/core/apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File ~/miniconda3/envs/melos/lib/python3.11/site-packages/pandas/core/apply.py:963, in FrameApply.apply_standard(self)
#     962 def apply_standard(self):
# --> 963     results, res_index = self.apply_series_generator()
#     965     # wrap results
#     966     return self.wrap_results(results, res_index)
#
# File ~/miniconda3/envs/melos/lib/python3.11/site-packages/pandas/core/apply.py:979, in FrameApply.apply_series_generator(self)
#     976 with option_context("mode.chained_assignment", None):
#     977     for i, v in enumerate(series_gen):
#     978         # ignore SettingWithCopy here in case the user mutates
# --> 979         results[i] = self.func(v, *self.args, **self.kwargs)
#     980         if isinstance(results[i], ABCSeries):
#     981             # If we have a view on v, we need to make a copy because
#     982             #  series_generator will swap out the underlying data
#     983             results[i] = results[i].copy(deep=False)
#
# Cell In[27], line 24, in <lambda>(row)
#      21             return cnv
#      22     return None
# ---> 24 common_mut_df['CN'] = common_mut_df.apply(lambda row: get_cn(row, ascat_cn_df), axis=1)
#
# Cell In[27], line 15, in get_cn(row, ascat_cn_df)
#      14 def get_cn(row, ascat_cn_df):
# ---> 15     mut = int(row['CHROM'])  # Convert CHROM to integer
#      16     for index, ascat_row in ascat_cn_df.iterrows():
#      17         startpos = int(ascat_row['startpos'])  # Convert startpos to integer
#
# ValueError: invalid literal for int() with base 10: 'chr1'

# %%
def get_cn (row):
    chrom = row['CHROM']
    cnv_df = cnv_rhab[cnv_rhab['chrom']==chrom]
    for row2 in cnv_df.iterrows():
        startpos = row2[1]['startpos']
        endpos = row2[1]['endpos']
        mutpos = row['POS']
        if mutpos >= startpos & mutpos < endpos:
            cn = row2[1]['CN']
            break
            
        # break
        # cn = None
    
    return cn

vaf_rhab['CN'] = vaf_rhab.progress_apply(lambda row: get_cn(row),axis=1)
vaf_rhab

# %% [markdown]
# ### 2.2 Obtain CN with Pybedtools

# %%
# Pybedtools package: see https://daler.github.io/pybedtools/main.html for documentation
 
# installed in melos conda environment through terminal with: pip install pybedtools

# Now import the library

import pybedtools

# Note that the path of BedTools has been modified in bashrc file to be able to execute pybedtools.

# %%
# To use pybedtools POS column of common_mut_df should have another coordenate like end position. To do so, duplicate the information of POS column

mutations_df = pd.DataFrame({
    'CHROM': common_mut_df['CHROM'],
    'start': common_mut_df['POS'],
    'end': common_mut_df['POS'] + 1, # duplicate this column so it is considered a "bed file"
    'REF': common_mut_df['REF'],
    'ALT': common_mut_df['ALT']
    
})

mutations_df
# Out:
#       CHROM     start       end REF ALT
# 0      chr1    104188    104189   C   A
# 1      chr1    843320    843321   G   A
# 2      chr1   1014876   1014877   G   T
# 3      chr1   1118520   1118521   C   T
# 4      chr1   1136548   1136549   G   T
# ...     ...       ...       ...  ..  ..
# 24290  chrY  26654389  26654390   A   G
# 24291  chrY  56823266  56823267   G   A
# 24292  chrY  56842066  56842067  CT  AC
# 24293  chrY  56842087  56842088   T   C
# 24294  chrY  56875391  56875392   G   A
#
# [24295 rows x 5 columns]

# %% [markdown]
# ### a. ASCAT CNV FILE

# %%
# Convert dataframes to a BedTool object so it could be processed with pybedtools
mutations_bt = pybedtools.BedTool.from_dataframe(mutations_df)
ascat_cn_bt = pybedtools.BedTool.from_dataframe(ascat_cnv_df)

# %%
# Use intersect method of Bedtools to intersect (see https://daler.github.io/pybedtools/intersections.html)
cnv_bt = ascat_cn_bt.intersect(mutations_bt) #save intersect table into a new dataframe

# %%
# Convert cnv bedtool object into a dataframe. 
cnv_df = cnv_bt.to_dataframe(header=None) # Note that "chrom, start, end, name" columns are by default even using "header = None".

# %%
cnv_df
# Out:
#       chrom      start        end  name
# 0      chr1     843320     843321     2
# 1      chr1    1014876    1014877     2
# 2      chr1    1118520    1118521     2
# 3      chr1    1136548    1136549     2
# 4      chr1    1182738    1182739     2
# ...     ...        ...        ...   ...
# 24056  chrX  153089070  153089071     1
# 24057  chrX  153635439  153635440     1
# 24058  chrX  154335112  154335113     1
# 24059  chrX  154408562  154408563     1
# 24060  chrX  154717434  154717435     1
#
# [24061 rows x 4 columns]

# %%
# Rename columns of cnv dataframe
cnv_df = cnv_df.rename(columns={'chrom':'CHROM','start':'POS','end':'POS2','name':'CN'})

# Drop POS2 column, which is an artificial column we created previously
cnv_df = cnv_df.drop(columns='POS2')

# %%
# We are loosing this number of mutations with the intersect method (?!)
len(mutations_df) - len(cnv_df)
# Out:
# 234

# %% [markdown]
# ### b. ASCAT SEGM FILE

# %%
# Convert dataframes to a BedTool object so it could be processed with pybedtools
mutations_bt = pybedtools.BedTool.from_dataframe(mutations_df)
ascat_segm_bt = pybedtools.BedTool.from_dataframe(ascat_segm_df)

# %%
# Use intersect method of Bedtools to intersect (see https://daler.github.io/pybedtools/intersections.html)
cnv_seg_bt = ascat_segm_bt.intersect(mutations_bt) #save intersect table into a new dataframe

# %%
# Convert cnv bedtool object into a dataframe. 
cnv_seg_df = cnv_seg_bt.to_dataframe(header=None) # Note that "chrom, start, end, name" columns are by default even using "header = None".

# %%
cnv_seg_df
# Out:
#       chrom      start        end  name
# 0      chr1     843320     843321     2
# 1      chr1    1014876    1014877     2
# 2      chr1    1118520    1118521     2
# 3      chr1    1136548    1136549     2
# 4      chr1    1182738    1182739     2
# ...     ...        ...        ...   ...
# 24056  chrX  153089070  153089071     1
# 24057  chrX  153635439  153635440     1
# 24058  chrX  154335112  154335113     1
# 24059  chrX  154408562  154408563     1
# 24060  chrX  154717434  154717435     1
#
# [24061 rows x 4 columns]

# %%
# Rename columns of cnv dataframe
cnv_seg_df = cnv_seg_df.rename(columns={'chrom':'CHROM','start':'POS','end':'POS2','name':'CN'})

# Drop POS2 column, which is an artificial column we created previously
cnv_seg_df = cnv_seg_df.drop(columns='POS2')

# %%
# We are loosing this number of mutations with the intersect method (?!)
len(mutations_df) - len(cnv_seg_df)
# Out:
# 234

# %% [markdown]
# ## 3/ Calculate CCF

# %% [markdown]
# ### a. ASCAT CNV FILE

# %%
# Merge intersect with common_mut_df adding left indicates: use only keys from left frame, preserve key order
mutations_cnv_df = pd.merge(common_mut_df,cnv_df,how='left')

# %%
mutations_cnv_df
# Out:
#       CHROM       POS ID REF ALT  QUAL FILTER  \
# 0      chr1    104188  .   C   A     .   PASS
# 1      chr1    843320  .   G   A     .   PASS
# 2      chr1   1014876  .   G   T     .   PASS
# 3      chr1   1118520  .   C   T     .   PASS
# 4      chr1   1136548  .   G   T     .   PASS
# ...     ...       ... ..  ..  ..   ...    ...
# 24290  chrY  26654389  .   A   G   864   PASS
# 24291  chrY  56823266  .   G   A     .   PASS
# 24292  chrY  56842066  .  CT  AC  1323   PASS
# 24293  chrY  56842087  .   T   C     .   PASS
# 24294  chrY  56875391  .   G   A   572   PASS
#
#                                                     INFO  \
# 0      AS_FilterStatus=SITE;AS_SB_TABLE=36,157|24,22;...
# 1      AS_FilterStatus=SITE;AS_SB_TABLE=105,87|38,31;...
# 2      AS_FilterStatus=SITE;AS_SB_TABLE=162,109|4,2;D...
# 3      AS_FilterStatus=SITE;AS_SB_TABLE=120,130|19,26...
# 4      AS_FilterStatus=SITE;AS_SB_TABLE=86,92|45,45;D...
# ...                                                  ...
# 24290  RC=GGAGAGGAAT;RC_IDX=6;RC_LF=GTAATGGAGT;RC_NM=...
# 24291  AS_FilterStatus=SITE;AS_SB_TABLE=487,411|29,27...
# 24292  LPS=6133;LPS_RC=42;RC=ACACACAG;RC_IDX=2;RC_LF=...
# 24293  AS_FilterStatus=SITE;AS_SB_TABLE=241,235|34,34...
# 24294  LPS=6136;LPS_RC=27;RC=GAAGGT;RC_IDX=2;RC_LF=AG...
#
#                                                   FORMAT  \
# 0                GT:AD:AF:DP:F1R2:F2R1:FAD:PGT:PID:PS:SB
# 1                           GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 2                           GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 3                           GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 4                           GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# ...                                                  ...
# 24290  GT:ABQ:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:...
# 24291                       GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 24292  GT:ABQ:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:...
# 24293            GT:AD:AF:DP:F1R2:F2R1:FAD:PGT:PID:PS:SB
# 24294  GT:ABQ:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:...
#
#                                                   NORMAL  ... t_alt_reads  \
# 0      0|0:124,0:7.128e-03:124:33,0:29,0:125,0:0|1:10...  ...          46
# 1      0/0:126,0:7.857e-03:126:58,0:63,0:125,0:67,59,0,0  ...          69
# 2      0/0:141,0:7.025e-03:141:64,0:69,0:139,0:85,56,0,0  ...           6
# 3      0/0:153,0:6.470e-03:153:62,0:83,0:152,0:78,75,0,0  ...          45
# 4      0/0:123,0:8.107e-03:123:60,0:59,0:121,0:57,66,0,0  ...          90
# ...                                                  ...  ...         ...
# 24290  ./.:0:57,0:0:58:2084,0:63,0:0,0,0,0,0,57,58:0:...  ...          41
# 24291  0/0:456,0:2.167e-03:456:195,0:201,0:448,0:238,...  ...          56
# 24292  ./.:0:290,0:0:290:9437,0:306,0:0,0,0,0,0,290,2...  ...          75
# 24293  0|0:295,0:3.303e-03:295:143,0:125,0:295,0:1|0:...  ...          68
# 24294  ./.:0:792,0:0:792:25196,0:817,0:0,0,0,0,0,792,...  ...          36
#
#        n_alt_reads  t_ref_reads  n_ref_reads       VAF  mut_type  \
# 0                0           69          124  0.400000       SNV
# 1                0           66          126  0.511111       SNV
# 2                0          130          141  0.044118       SNV
# 3                0           97          153  0.316901       SNV
# 4                0           55          123  0.620690       SNV
# ...            ...          ...          ...       ...       ...
# 24290            0           19           57  0.683000       SNV
# 24291            0          442          456  0.112450       SNV
# 24292            0          169          290  0.305000       MNV
# 24293            0          181          295  0.273092       SNV
# 24294            0          796          792  0.043000       SNV
#
#        Caller_intersec   SAMPLE                  mut   CN
# 0       Mutect_Strelka  sarcoma      chr1_104188_C_A  NaN
# 1       Mutect_Strelka  sarcoma      chr1_843320_G_A  2.0
# 2       Mutect_Strelka  sarcoma     chr1_1014876_G_T  2.0
# 3       Mutect_Strelka  sarcoma     chr1_1118520_C_T  2.0
# 4       Mutect_Strelka  sarcoma     chr1_1136548_G_T  2.0
# ...                ...      ...                  ...  ...
# 24290     Strelka_SAGE  sarcoma    chrY_26654389_A_G  NaN
# 24291   Mutect_Strelka  sarcoma    chrY_56823266_G_A  NaN
# 24292      Mutect_SAGE  sarcoma  chrY_56842066_CT_AC  NaN
# 24293   Mutect_Strelka  sarcoma    chrY_56842087_T_C  NaN
# 24294      Mutect_SAGE  sarcoma    chrY_56875391_G_A  NaN
#
# [24295 rows x 25 columns]

# %%
# Check in CN column which mutations have non NaN values. Note that returns the same number of rows of cnv_df length.
nan_values = mutations_cnv_df[~mutations_cnv_df['CN'].isna()]

# %%
nan_values
# Out:
#       CHROM        POS ID REF ALT QUAL FILTER  \
# 1      chr1     843320  .   G   A    .   PASS
# 2      chr1    1014876  .   G   T    .   PASS
# 3      chr1    1118520  .   C   T    .   PASS
# 4      chr1    1136548  .   G   T    .   PASS
# 5      chr1    1182738  .   C   T    .   PASS
# ...     ...        ... ..  ..  ..  ...    ...
# 24166  chrX  153089070  .   A   T    .   PASS
# 24167  chrX  153635439  .   C   A    .   PASS
# 24168  chrX  154335112  .   C   A    .   PASS
# 24169  chrX  154408562  .   C   T    .   PASS
# 24170  chrX  154717434  .   A   C    .   PASS
#
#                                                     INFO  \
# 1      AS_FilterStatus=SITE;AS_SB_TABLE=105,87|38,31;...
# 2      AS_FilterStatus=SITE;AS_SB_TABLE=162,109|4,2;D...
# 3      AS_FilterStatus=SITE;AS_SB_TABLE=120,130|19,26...
# 4      AS_FilterStatus=SITE;AS_SB_TABLE=86,92|45,45;D...
# 5      AS_FilterStatus=SITE;AS_SB_TABLE=136,140|23,19...
# ...                                                  ...
# 24166  AS_FilterStatus=SITE;AS_SB_TABLE=33,46|23,34;D...
# 24167  AS_FilterStatus=SITE;AS_SB_TABLE=46,42|27,28;D...
# 24168  AS_FilterStatus=SITE;AS_SB_TABLE=93,76|3,2;DP=...
# 24169  AS_FilterStatus=SITE;AS_SB_TABLE=68,58|13,11;D...
# 24170  AS_FilterStatus=SITE;AS_SB_TABLE=69,98|3,5;DP=...
#
#                              FORMAT  \
# 1      GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 2      GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 3      GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 4      GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 5      GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# ...                             ...
# 24166  GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 24167  GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 24168  GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 24169  GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 24170  GT:AD:AF:DP:F1R2:F2R1:FAD:SB
#
#                                                   NORMAL  ... t_alt_reads  \
# 1      0/0:126,0:7.857e-03:126:58,0:63,0:125,0:67,59,0,0  ...          69
# 2      0/0:141,0:7.025e-03:141:64,0:69,0:139,0:85,56,0,0  ...           6
# 3      0/0:153,0:6.470e-03:153:62,0:83,0:152,0:78,75,0,0  ...          45
# 4      0/0:123,0:8.107e-03:123:60,0:59,0:121,0:57,66,0,0  ...          90
# 5      0/0:167,0:5.950e-03:167:85,0:68,0:165,0:84,83,0,0  ...          42
# ...                                                  ...  ...         ...
# 24166         0/0:54,0:0.018:54:16,0:36,0:54,0:24,30,0,0  ...          57
# 24167         0/0:67,0:0.014:67:33,0:34,0:67,0:36,31,0,0  ...          55
# 24168         0/0:76,0:0.013:76:31,0:43,0:75,0:37,39,0,0  ...           5
# 24169         0/0:72,0:0.014:72:32,0:36,0:69,0:39,33,0,0  ...          24
# 24170         0/0:86,0:0.011:86:47,0:34,0:85,0:39,47,0,0  ...           8
#
#        n_alt_reads  t_ref_reads  n_ref_reads       VAF  mut_type  \
# 1                0           66          126  0.511111       SNV
# 2                0          130          141  0.044118       SNV
# 3                0           97          153  0.316901       SNV
# 4                0           55          123  0.620690       SNV
# 5                0          109          167  0.278146       SNV
# ...            ...          ...          ...       ...       ...
# 24166            0           25           54  0.695122       SNV
# 24167            0           21           67  0.723684       SNV
# 24168            0           93           76  0.051020       SNV
# 24169            0           54           72  0.307692       SNV
# 24170            0           81           86  0.089888       SNV
#
#        Caller_intersec   SAMPLE                 mut   CN
# 1       Mutect_Strelka  sarcoma     chr1_843320_G_A  2.0
# 2       Mutect_Strelka  sarcoma    chr1_1014876_G_T  2.0
# 3       Mutect_Strelka  sarcoma    chr1_1118520_C_T  2.0
# 4       Mutect_Strelka  sarcoma    chr1_1136548_G_T  2.0
# 5       Mutect_Strelka  sarcoma    chr1_1182738_C_T  2.0
# ...                ...      ...                 ...  ...
# 24166   Mutect_Strelka  sarcoma  chrX_153089070_A_T  1.0
# 24167   Mutect_Strelka  sarcoma  chrX_153635439_C_A  1.0
# 24168   Mutect_Strelka  sarcoma  chrX_154335112_C_A  1.0
# 24169   Mutect_Strelka  sarcoma  chrX_154408562_C_T  1.0
# 24170   Mutect_Strelka  sarcoma  chrX_154717434_A_C  1.0
#
# [24061 rows x 25 columns]

# %%
# Add 2 in CN with NaN values, because these positions despite were not in the cnv file are diploid
mutations_cnv_df['CN'].fillna(2, inplace=True) 
# Convert columns to float so they are operable to calculate CCF
mutations_cnv_df[['VAF','CN']] = mutations_cnv_df[['VAF','CN']].astype(float)

# %%
mutations_cnv_df
# Out:
#       CHROM       POS ID REF ALT  QUAL FILTER  \
# 0      chr1    104188  .   C   A     .   PASS
# 1      chr1    843320  .   G   A     .   PASS
# 2      chr1   1014876  .   G   T     .   PASS
# 3      chr1   1118520  .   C   T     .   PASS
# 4      chr1   1136548  .   G   T     .   PASS
# ...     ...       ... ..  ..  ..   ...    ...
# 24290  chrY  26654389  .   A   G   864   PASS
# 24291  chrY  56823266  .   G   A     .   PASS
# 24292  chrY  56842066  .  CT  AC  1323   PASS
# 24293  chrY  56842087  .   T   C     .   PASS
# 24294  chrY  56875391  .   G   A   572   PASS
#
#                                                     INFO  \
# 0      AS_FilterStatus=SITE;AS_SB_TABLE=36,157|24,22;...
# 1      AS_FilterStatus=SITE;AS_SB_TABLE=105,87|38,31;...
# 2      AS_FilterStatus=SITE;AS_SB_TABLE=162,109|4,2;D...
# 3      AS_FilterStatus=SITE;AS_SB_TABLE=120,130|19,26...
# 4      AS_FilterStatus=SITE;AS_SB_TABLE=86,92|45,45;D...
# ...                                                  ...
# 24290  RC=GGAGAGGAAT;RC_IDX=6;RC_LF=GTAATGGAGT;RC_NM=...
# 24291  AS_FilterStatus=SITE;AS_SB_TABLE=487,411|29,27...
# 24292  LPS=6133;LPS_RC=42;RC=ACACACAG;RC_IDX=2;RC_LF=...
# 24293  AS_FilterStatus=SITE;AS_SB_TABLE=241,235|34,34...
# 24294  LPS=6136;LPS_RC=27;RC=GAAGGT;RC_IDX=2;RC_LF=AG...
#
#                                                   FORMAT  \
# 0                GT:AD:AF:DP:F1R2:F2R1:FAD:PGT:PID:PS:SB
# 1                           GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 2                           GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 3                           GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 4                           GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# ...                                                  ...
# 24290  GT:ABQ:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:...
# 24291                       GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 24292  GT:ABQ:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:...
# 24293            GT:AD:AF:DP:F1R2:F2R1:FAD:PGT:PID:PS:SB
# 24294  GT:ABQ:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:...
#
#                                                   NORMAL  ... t_alt_reads  \
# 0      0|0:124,0:7.128e-03:124:33,0:29,0:125,0:0|1:10...  ...          46
# 1      0/0:126,0:7.857e-03:126:58,0:63,0:125,0:67,59,0,0  ...          69
# 2      0/0:141,0:7.025e-03:141:64,0:69,0:139,0:85,56,0,0  ...           6
# 3      0/0:153,0:6.470e-03:153:62,0:83,0:152,0:78,75,0,0  ...          45
# 4      0/0:123,0:8.107e-03:123:60,0:59,0:121,0:57,66,0,0  ...          90
# ...                                                  ...  ...         ...
# 24290  ./.:0:57,0:0:58:2084,0:63,0:0,0,0,0,0,57,58:0:...  ...          41
# 24291  0/0:456,0:2.167e-03:456:195,0:201,0:448,0:238,...  ...          56
# 24292  ./.:0:290,0:0:290:9437,0:306,0:0,0,0,0,0,290,2...  ...          75
# 24293  0|0:295,0:3.303e-03:295:143,0:125,0:295,0:1|0:...  ...          68
# 24294  ./.:0:792,0:0:792:25196,0:817,0:0,0,0,0,0,792,...  ...          36
#
#        n_alt_reads  t_ref_reads  n_ref_reads       VAF  mut_type  \
# 0                0           69          124  0.400000       SNV
# 1                0           66          126  0.511111       SNV
# 2                0          130          141  0.044118       SNV
# 3                0           97          153  0.316901       SNV
# 4                0           55          123  0.620690       SNV
# ...            ...          ...          ...       ...       ...
# 24290            0           19           57  0.683000       SNV
# 24291            0          442          456  0.112450       SNV
# 24292            0          169          290  0.305000       MNV
# 24293            0          181          295  0.273092       SNV
# 24294            0          796          792  0.043000       SNV
#
#        Caller_intersec   SAMPLE                  mut   CN
# 0       Mutect_Strelka  sarcoma      chr1_104188_C_A  2.0
# 1       Mutect_Strelka  sarcoma      chr1_843320_G_A  2.0
# 2       Mutect_Strelka  sarcoma     chr1_1014876_G_T  2.0
# 3       Mutect_Strelka  sarcoma     chr1_1118520_C_T  2.0
# 4       Mutect_Strelka  sarcoma     chr1_1136548_G_T  2.0
# ...                ...      ...                  ...  ...
# 24290     Strelka_SAGE  sarcoma    chrY_26654389_A_G  2.0
# 24291   Mutect_Strelka  sarcoma    chrY_56823266_G_A  2.0
# 24292      Mutect_SAGE  sarcoma  chrY_56842066_CT_AC  2.0
# 24293   Mutect_Strelka  sarcoma    chrY_56842087_T_C  2.0
# 24294      Mutect_SAGE  sarcoma    chrY_56875391_G_A  2.0
#
# [24295 rows x 25 columns]

# %%
def get_ccf(row):
    row = row['VAF'] * (purity * row['CN'] + (1 - purity) * 2) / purity
    return row

mutations_cnv_df['CCF'] = mutations_cnv_df.progress_apply(get_ccf, axis=1)
# Out:
#   0%|          | 0/24295 [00:00<?, ?it/s]

# %%
mutations_cnv_df.head()
# Out:
#   CHROM      POS ID REF ALT QUAL FILTER  \
# 0  chr1   104188  .   C   A    .   PASS
# 1  chr1   843320  .   G   A    .   PASS
# 2  chr1  1014876  .   G   T    .   PASS
# 3  chr1  1118520  .   C   T    .   PASS
# 4  chr1  1136548  .   G   T    .   PASS
#
#                                                 INFO  \
# 0  AS_FilterStatus=SITE;AS_SB_TABLE=36,157|24,22;...
# 1  AS_FilterStatus=SITE;AS_SB_TABLE=105,87|38,31;...
# 2  AS_FilterStatus=SITE;AS_SB_TABLE=162,109|4,2;D...
# 3  AS_FilterStatus=SITE;AS_SB_TABLE=120,130|19,26...
# 4  AS_FilterStatus=SITE;AS_SB_TABLE=86,92|45,45;D...
#
#                                     FORMAT  \
# 0  GT:AD:AF:DP:F1R2:F2R1:FAD:PGT:PID:PS:SB
# 1             GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 2             GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 3             GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 4             GT:AD:AF:DP:F1R2:F2R1:FAD:SB
#
#                                               NORMAL  ... n_alt_reads  \
# 0  0|0:124,0:7.128e-03:124:33,0:29,0:125,0:0|1:10...  ...           0
# 1  0/0:126,0:7.857e-03:126:58,0:63,0:125,0:67,59,0,0  ...           0
# 2  0/0:141,0:7.025e-03:141:64,0:69,0:139,0:85,56,0,0  ...           0
# 3  0/0:153,0:6.470e-03:153:62,0:83,0:152,0:78,75,0,0  ...           0
# 4  0/0:123,0:8.107e-03:123:60,0:59,0:121,0:57,66,0,0  ...           0
#
#    t_ref_reads  n_ref_reads       VAF  mut_type  Caller_intersec   SAMPLE  \
# 0           69          124  0.400000       SNV   Mutect_Strelka  sarcoma
# 1           66          126  0.511111       SNV   Mutect_Strelka  sarcoma
# 2          130          141  0.044118       SNV   Mutect_Strelka  sarcoma
# 3           97          153  0.316901       SNV   Mutect_Strelka  sarcoma
# 4           55          123  0.620690       SNV   Mutect_Strelka  sarcoma
#
#                 mut   CN       CCF
# 0   chr1_104188_C_A  2.0  1.333333
# 1   chr1_843320_G_A  2.0  1.703704
# 2  chr1_1014876_G_T  2.0  0.147059
# 3  chr1_1118520_C_T  2.0  1.056338
# 4  chr1_1136548_G_T  2.0  2.068966
#
# [5 rows x 26 columns]

# %% [markdown]
# ### b. ASCAT SEGM FILE

# %%
# Merge intersect with common_mut_df adding left indicates: use only keys from left frame, preserve key order
mutations_segm_df = pd.merge(common_mut_df,cnv_seg_df,how='left')

# %%
# Add 2 in CN with NaN values, because these positions despite were not in the cnv file are diploid
mutations_segm_df['CN'].fillna(2, inplace=True) 
# Convert columns to float so they are operable to calculate CCF
mutations_segm_df[['VAF','CN']] = mutations_segm_df[['VAF','CN']].astype(float)

# %%
# Apply previous defined function get_ccf

mutations_segm_df['CCF'] = mutations_segm_df.progress_apply(get_ccf, axis=1)
# Out:
#   0%|          | 0/24295 [00:00<?, ?it/s]

# %%
mutations_segm_df.head()
# Out:
#   CHROM      POS ID REF ALT QUAL FILTER  \
# 0  chr1   104188  .   C   A    .   PASS
# 1  chr1   843320  .   G   A    .   PASS
# 2  chr1  1014876  .   G   T    .   PASS
# 3  chr1  1118520  .   C   T    .   PASS
# 4  chr1  1136548  .   G   T    .   PASS
#
#                                                 INFO  \
# 0  AS_FilterStatus=SITE;AS_SB_TABLE=36,157|24,22;...
# 1  AS_FilterStatus=SITE;AS_SB_TABLE=105,87|38,31;...
# 2  AS_FilterStatus=SITE;AS_SB_TABLE=162,109|4,2;D...
# 3  AS_FilterStatus=SITE;AS_SB_TABLE=120,130|19,26...
# 4  AS_FilterStatus=SITE;AS_SB_TABLE=86,92|45,45;D...
#
#                                     FORMAT  \
# 0  GT:AD:AF:DP:F1R2:F2R1:FAD:PGT:PID:PS:SB
# 1             GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 2             GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 3             GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 4             GT:AD:AF:DP:F1R2:F2R1:FAD:SB
#
#                                               NORMAL  ... n_alt_reads  \
# 0  0|0:124,0:7.128e-03:124:33,0:29,0:125,0:0|1:10...  ...           0
# 1  0/0:126,0:7.857e-03:126:58,0:63,0:125,0:67,59,0,0  ...           0
# 2  0/0:141,0:7.025e-03:141:64,0:69,0:139,0:85,56,0,0  ...           0
# 3  0/0:153,0:6.470e-03:153:62,0:83,0:152,0:78,75,0,0  ...           0
# 4  0/0:123,0:8.107e-03:123:60,0:59,0:121,0:57,66,0,0  ...           0
#
#    t_ref_reads  n_ref_reads       VAF  mut_type  Caller_intersec   SAMPLE  \
# 0           69          124  0.400000       SNV   Mutect_Strelka  sarcoma
# 1           66          126  0.511111       SNV   Mutect_Strelka  sarcoma
# 2          130          141  0.044118       SNV   Mutect_Strelka  sarcoma
# 3           97          153  0.316901       SNV   Mutect_Strelka  sarcoma
# 4           55          123  0.620690       SNV   Mutect_Strelka  sarcoma
#
#                 mut   CN       CCF
# 0   chr1_104188_C_A  2.0  1.333333
# 1   chr1_843320_G_A  2.0  1.703704
# 2  chr1_1014876_G_T  2.0  0.147059
# 3  chr1_1118520_C_T  2.0  1.056338
# 4  chr1_1136548_G_T  2.0  2.068966
#
# [5 rows x 26 columns]

# %% [markdown]
# ## 4/ Histograms representing CCF

# %% [markdown]
# ### A. ASCAT CNV FILE

# %%
# # Check in CCF column which mutations have non NaN values. Note that returns the same number of rows of cnv_df length.
# mutations_ccf_df = mutations_cnv_df[~mutations_cnv_df['CCF'].isna()]

# %%
ccf = mutations_cnv_df['CCF'].copy()  # Extract the 'CCF' column
ccf = pd.to_numeric(ccf, errors='coerce')  # Convert values to numeric, coerce errors

# %%
ccf
# Out:
# 0        1.333333
# 1        1.703704
# 2        0.147059
# 3        1.056338
# 4        2.068966
#            ...
# 24290    2.276667
# 24291    0.374833
# 24292    1.016667
# 24293    0.910308
# 24294    0.143333
# Name: CCF, Length: 24295, dtype: float64

# %%
plt.hist(ccf.tolist(), bins = 400, color = 'orange')
plt.xlim([0,6])
plt.ylabel('Number of mutations',  fontsize=16)
plt.xlabel('CCF', fontsize=16)
plt.title('CCF ASCAT in Sarcoma sample', fontsize=16, weight ='bold')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show(ccf.tolist())

# %%
plt.hist(ccf.tolist(), bins = 400, color = 'orange')
plt.xlim([0,6])
plt.ylabel('Número de mutaciones sarcoma',  fontsize=16)
plt.xlabel('CCF', fontsize=16)
plt.title('ASCAT', fontsize=16, weight ='bold')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show(ccf.tolist())

# %% [markdown]
# ### B. ASCAT SEGM FILE

# %%
ccf_seg = mutations_segm_df['CCF'].copy()  # Extract the 'CCF' column
ccf_seg = pd.to_numeric(ccf_seg, errors='coerce')  # Convert values to numeric, coerce errors

# %%
plt.hist(ccf_seg.tolist(), bins = 400, color = "orange")
plt.xlim([0,6])
plt.ylabel('Number of mutations')
plt.xlabel('CCF')
plt.title('CCF ASCAT_segm in Sarcoma sample')
plt.show(ccf_seg.tolist())
