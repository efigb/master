# %% [markdown]
# # Identication of the consensus mutations between callers in SARCOMA-lung sample

# %%
# Needed basic packages
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from tqdm.notebook import tqdm
from matplotlib_venn import venn3

# %% [markdown]
# # 1/ Importing filtered mutation tables

# %%
import pandas as pd

# Import filtered mutation files 
mutect_df = pd.read_csv('/workspace/projects/sjd_melos/MAFs_tables/1_callers/Lung_Mutect2_VAF.tsv.gz', sep="\t", header=0)
strelka_df = pd.read_csv('/workspace/projects/sjd_melos/MAFs_tables/1_callers/Lung_Strelka_VAF_all.tsv.gz', sep="\t", header=0)
sage_df = pd.read_csv('/workspace/projects/sjd_melos/MAFs_tables/1_callers/Lung_SAGE_VAF.tsv.gz', sep="\t", header=0)

# %%
# Check dimensions of the dataframes so the number of rows is correct
print('Dimensions of melanoma mutations found with Mutect2 (columns x rows):', mutect_df.shape)
print('Dimensions of melanoma mutations found with Strelka (columns x rows):', strelka_df.shape)
print('Dimensions of melanoma mutations found with SAGE (columns x rows):', sage_df.shape)
# Out:
# Dimensions of melanoma mutations found with Mutect2 (columns x rows): (23011, 22)
# Dimensions of melanoma mutations found with Strelka (columns x rows): (24072, 20)
# Dimensions of melanoma mutations found with SAGE (columns x rows): (20454, 22)

# %%
sage_df.head()
# Out:
#   CHROM      POS ID REF ALT  QUAL FILTER  \
# 0  chr1   104188  .   C   A   764   PASS
# 1  chr1   843320  .   G   A  2303   PASS
# 2  chr1  1118520  .   C   T   813   PASS
# 3  chr1  1136548  .   G   T  1894   PASS
# 4  chr1  1182738  .   C   T   898   PASS
#
#                                                 INFO  \
# 0  RC=TAAACACACACG;RC_IDX=2;RC_LF=CACACACACA;RC_N...
# 1  LPS=1;LPS_RC=4;RC=GAAACA;RC_IDX=3;RC_LF=CAAAGA...
# 2  RC=TGTGA;RC_IDX=2;RC_LF=GACGAGGCCA;RC_NM=1;RC_...
# 3  RC=CATCC;RC_IDX=2;RC_LF=GCTGAGTGGC;RC_NM=1;RC_...
# 4  RC=GGTGTGTGG;RC_IDX=2;RC_LF=GCTGGGGCCA;RC_NM=1...
#
#                                               FORMAT  \
# 0  GT:ABQ:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:...
# 1  GT:ABQ:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:...
# 2  GT:ABQ:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:...
# 3  GT:ABQ:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:...
# 4  GT:ABQ:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:...
#
#                                               NORMAL  ... n_AF  t_DP  n_DP  \
# 0  ./.:0:197,0:0:197:6097,0:206,0:0,0,0,0,0,197,1...  ...  0.0   217   197
# 1  ./.:0:125,0:0:125:3974,0:127,0:0,0,0,0,0,125,1...  ...  0.0   107   125
# 2  ./.:0:148,0:0:148:4278,0:155,0:0,0,0,0,0,148,1...  ...  0.0   133   148
# 3  ./.:0:124,0:0:124:3979,0:128,0:0,0,0,0,0,124,1...  ...  0.0   122   124
# 4  ./.:0:159,0:0:159:4649,0:173,0:0,0,0,0,0,159,1...  ...  0.0   130   159
#
#    t_ref_reads  n_ref_reads  t_alt_reads  n_alt_reads    VAF  mut_type  \
# 0          163          197           54            0  0.249       SNV
# 1           27          125           80            0  0.748       SNV
# 2           92          148           41            0  0.308       SNV
# 3           41          124           81            0  0.664       SNV
# 4           80          159           50            0  0.385       SNV
#
#          SAMPLE
# 0  sarcoma-lung
# 1  sarcoma-lung
# 2  sarcoma-lung
# 3  sarcoma-lung
# 4  sarcoma-lung
#
# [5 rows x 22 columns]

# %% [markdown]
# ## a) Find the number of common mutations with the callers

# %%
#Add a new column in mutect/strelka tables joining the CHROM-POS-REF-ALT information and extract it as a list

mutect_df['mut'] = mutect_df.apply(lambda row: row['CHROM']+'_'+str(row['POS'])+'_'+row['REF']+'_'+row['ALT'],axis=1)
m_list = mutect_df['mut'].tolist()

strelka_df['mut'] = strelka_df.apply(lambda row: row['CHROM']+'_'+str(row['POS'])+'_'+row['REF']+'_'+row['ALT'],axis=1)
s_list = strelka_df['mut'].tolist()

sage_df['mut'] = sage_df.apply(lambda row: row['CHROM']+'_'+str(row['POS'])+'_'+row['REF']+'_'+row['ALT'],axis=1)
sage_list = sage_df['mut'].tolist()

# Convert to a set function to obtain a unique collection of elements
set_m = set(m_list)
set_s = set(s_list)
set_sage = set(sage_list)

# %%
# Check if number of mutations coincides with previous data
print(len(set_m))
print(len(set_s))
print(len(set_sage))
# Out:
# 23011
# 24072
# 20454

# %%
venn3([set_m,set_s, set_sage],set_labels=['Mutect','Strelka','SAGE'])
plt.title('Mutaciones Sarcoma (pulmón)')
# Out:
# Text(0.5, 1.0, 'Mutaciones Sarcoma (pulmón)')

# %% [markdown]
# ## b) Obtain the list of mutations in a minimum of 2 callers

# %%
# Now merge based on "mut" column, in two-by-two comparisons since we want the common mutations in a minimum of two callers (how=inner)
mutstr_common_df = pd.merge(mutect_df, strelka_df, how ="inner", on=['mut'], suffixes=['_Mut','_Str'], indicator = True)
mutsage_common_df = pd.merge(mutect_df, sage_df, how ="inner", on=['mut'], suffixes=['_Mut','_SAGE'], indicator = True)
strsage_common_df = pd.merge(strelka_df, sage_df, how ="inner", on=['mut'], suffixes=['_Str','_SAGE'], indicator = True)

# Now we have the common mutations between callers.
# Since we priorize information from SAGE > Mutect2 callers, we will delete all information from the caller (Strelka information is not considered in any case)
mutstr_common_df = mutstr_common_df.loc[:, ~mutstr_common_df.columns.str.endswith('_Str')] # here we delete columns from Strelka and remain Mutect2 columns
mutsage_common_df = mutsage_common_df.loc[:, ~mutsage_common_df.columns.str.endswith('_Mut')] # here we delete columns from mutect and remain SAGE columns
strsage_common_df = strsage_common_df.loc[:, ~strsage_common_df.columns.str.endswith('_Str')] # here we delete columns from Strelka and remain SAGE columns

# %%
strsage_common_df
# Out:
#       Mut_type                 mut CHROM_SAGE  POS_SAGE ID_SAGE REF_SAGE  \
# 0          SNV     chr1_104188_C_A       chr1    104188       .        C
# 1          SNV     chr1_843320_G_A       chr1    843320       .        G
# 2          SNV    chr1_1118520_C_T       chr1   1118520       .        C
# 3          SNV    chr1_1136548_G_T       chr1   1136548       .        G
# 4          SNV    chr1_1182738_C_T       chr1   1182738       .        C
# ...        ...                 ...        ...       ...     ...      ...
# 19824    INDEL  chrY_11362309_CA_C       chrY  11362309       .       CA
# 19825    INDEL  chrY_11712779_AG_A       chrY  11712779       .       AG
# 19826    INDEL  chrY_13880669_AG_A       chrY  13880669       .       AG
# 19827    INDEL  chrY_16426090_TA_T       chrY  16426090       .       TA
# 19828    INDEL  chrY_16962796_AC_A       chrY  16962796       .       AC
#
#       ALT_SAGE  QUAL_SAGE FILTER_SAGE  \
# 0            A        764        PASS
# 1            A       2303        PASS
# 2            T        813        PASS
# 3            T       1894        PASS
# 4            T        898        PASS
# ...        ...        ...         ...
# 19824        C        287        PASS
# 19825        A        738        PASS
# 19826        A        609        PASS
# 19827        T        655        PASS
# 19828        A        601        PASS
#
#                                                INFO_SAGE  ... t_DP_SAGE  \
# 0      RC=TAAACACACACG;RC_IDX=2;RC_LF=CACACACACA;RC_N...  ...       217
# 1      LPS=1;LPS_RC=4;RC=GAAACA;RC_IDX=3;RC_LF=CAAAGA...  ...       107
# 2      RC=TGTGA;RC_IDX=2;RC_LF=GACGAGGCCA;RC_NM=1;RC_...  ...       133
# 3      RC=CATCC;RC_IDX=2;RC_LF=GCTGAGTGGC;RC_NM=1;RC_...  ...       122
# 4      RC=GGTGTGTGG;RC_IDX=2;RC_LF=GCTGGGGCCA;RC_NM=1...  ...       130
# ...                                                  ...  ...       ...
# 19824  MH=A;RC=AACAAAAAAAGT;RC_IDX=2;RC_LF=ATAGCCTACC...  ...        99
# 19825  MH=G;RC=AAAGA;RC_IDX=2;RC_LF=AATGGAACTG;RC_MH=...  ...        56
# 19826  MH=G;RC=AAAGA;RC_IDX=2;RC_LF=ATCATCAATA;RC_MH=...  ...        48
# 19827  MH=A;RC=ATATATAAATT;RC_IDX=5;RC_LF=AGAAAATACC;...  ...        55
# 19828  LPS=5878;LPS_RC=27;RC=CAAAG;RC_IDX=2;RC_LF=AGA...  ...        57
#
#       n_DP_SAGE t_ref_reads_SAGE  n_ref_reads_SAGE  t_alt_reads_SAGE  \
# 0           197              163               197                54
# 1           125               27               125                80
# 2           148               92               148                41
# 3           124               41               124                81
# 4           159               80               159                50
# ...         ...              ...               ...               ...
# 19824       102               78               102                20
# 19825        61               16                61                40
# 19826        72               15                72                33
# 19827        49               18                49                37
# 19828        67               23                67                34
#
#        n_alt_reads_SAGE  VAF_SAGE  mut_type   SAMPLE_SAGE  _merge
# 0                     0     0.249       SNV  sarcoma-lung    both
# 1                     0     0.748       SNV  sarcoma-lung    both
# 2                     0     0.308       SNV  sarcoma-lung    both
# 3                     0     0.664       SNV  sarcoma-lung    both
# 4                     0     0.385       SNV  sarcoma-lung    both
# ...                 ...       ...       ...           ...     ...
# 19824                 0     0.202     INDEL  sarcoma-lung    both
# 19825                 0     0.714     INDEL  sarcoma-lung    both
# 19826                 0     0.688     INDEL  sarcoma-lung    both
# 19827                 0     0.673     INDEL  sarcoma-lung    both
# 19828                 0     0.596     INDEL  sarcoma-lung    both
#
# [19829 rows x 25 columns]

# %%
# Now merge the three callers to obtain those mutations that are shared by all of them
mutstrsage_common_df = pd.merge(mutstr_common_df, sage_df, how ="inner", on=['mut'], suffixes=['_MutStr','_SAGE'])
mutstrsage_common_df = mutstrsage_common_df.loc[:, ~mutstrsage_common_df.columns.str.endswith('_MutStr')] # here we delete columns from Mutect2-Strelka and remain SAGE columns

# %%
mutstrsage_common_df.head()
# Out:
#   CHROM_Mut  POS_Mut ID_Mut REF_Mut ALT_Mut QUAL_Mut FILTER_Mut  \
# 0      chr1   104188      .       C       A        .       PASS
# 1      chr1   843320      .       G       A        .       PASS
# 2      chr1  1118520      .       C       T        .       PASS
# 3      chr1  1136548      .       G       T        .       PASS
# 4      chr1  1182738      .       C       T        .       PASS
#
#                                             INFO_Mut  \
# 0  AS_FilterStatus=SITE;AS_SB_TABLE=40,144|18,33;...
# 1  AS_FilterStatus=SITE;AS_SB_TABLE=81,70|44,36;D...
# 2  AS_FilterStatus=SITE;AS_SB_TABLE=114,133|12,30...
# 3  AS_FilterStatus=SITE;AS_SB_TABLE=72,93|44,38;D...
# 4  AS_FilterStatus=SITE;AS_SB_TABLE=126,126|27,25...
#
#                                 FORMAT_Mut  \
# 0  GT:AD:AF:DP:F1R2:F2R1:FAD:PGT:PID:PS:SB
# 1             GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 2             GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 3             GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 4             GT:AD:AF:DP:F1R2:F2R1:FAD:SB
#
#                                           NORMAL_Mut  ... n_AF_SAGE  t_DP  \
# 0  0|0:124,0:7.177e-03:124:33,0:29,0:124,0:0|1:10...  ...       0.0   217
# 1  0/0:126,0:7.857e-03:126:58,0:63,0:125,0:67,59,0,0  ...       0.0   107
# 2  0/0:153,0:6.470e-03:153:62,0:83,0:152,0:78,75,0,0  ...       0.0   133
# 3  0/0:123,0:8.107e-03:123:60,0:59,0:121,0:57,66,0,0  ...       0.0   122
# 4  0/0:167,0:5.950e-03:167:85,0:68,0:165,0:84,83,0,0  ...       0.0   130
#
#    n_DP  t_ref_reads  n_ref_reads  t_alt_reads  n_alt_reads    VAF  \
# 0   197          163          197           54            0  0.249
# 1   125           27          125           80            0  0.748
# 2   148           92          148           41            0  0.308
# 3   124           41          124           81            0  0.664
# 4   159           80          159           50            0  0.385
#
#   mut_type_SAGE        SAMPLE
# 0           SNV  sarcoma-lung
# 1           SNV  sarcoma-lung
# 2           SNV  sarcoma-lung
# 3           SNV  sarcoma-lung
# 4           SNV  sarcoma-lung
#
# [5 rows x 44 columns]

# %%
# Add Caller intersection name as a column
mutstr_common_df = mutstr_common_df.assign(Caller_intersec='Mutect_Strelka')
mutsage_common_df = mutsage_common_df.assign(Caller_intersec='Mutect_SAGE')
strsage_common_df = strsage_common_df.assign(Caller_intersec='Strelka_SAGE')
mutstrsage_common_df = strsage_common_df.assign(Caller_intersec='Mutect_Strelka_SAGE')

# %%
for col in mutstr_common_df.columns:
    print(col)
# Out:
# CHROM_Mut
# POS_Mut
# ID_Mut
# REF_Mut
# ALT_Mut
# QUAL_Mut
# FILTER_Mut
# INFO_Mut
# FORMAT_Mut
# NORMAL_Mut
# TUMOR_Mut
# t_AF
# n_AF
# t_DP_Mut
# n_DP_Mut
# t_ref_reads_Mut
# n_ref_reads_Mut
# t_alt_reads_Mut
# n_alt_reads_Mut
# VAF_Mut
# mut_type
# SAMPLE_Mut
# mut
# Mut_type
# _merge
# Caller_intersec

# %%
# Define a custom function to remove the indexes from columns
def remove_colindex(column):
    return column.replace('_Mut', '')

def remove_colindex2(column):
    return column.replace('_SAGE', '')

# Apply the custom function to the date column names using a list comprehension
mutstr_common_df.columns = [remove_colindex(col) for col in mutstr_common_df.columns]
mutsage_common_df.columns = [remove_colindex2(col) for col in mutsage_common_df.columns]
strsage_common_df.columns = [remove_colindex2(col) for col in strsage_common_df.columns]
mutstrsage_common_df.columns = [remove_colindex2(col) for col in mutstrsage_common_df.columns]

# %%
# Now that each intersection is controlled in a column, reorder and rename all the other columns prior to merge 
# Reorder columns according to a list with the same column names
cols = ['CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'NORMAL', 'TUMOR','t_AF', 'n_AF', 't_DP','n_DP','t_alt_reads', 'n_alt_reads', 't_ref_reads','n_ref_reads', 'VAF', 'mut_type', 'Caller_intersec', 'SAMPLE','mut']
mutstr_common_df = mutstr_common_df.reindex(cols, axis = 1)
strsage_common_df = strsage_common_df.reindex(cols, axis = 1)
mutsage_common_df = mutsage_common_df.reindex(cols, axis = 1)
strsage_common_df = strsage_common_df.reindex(cols, axis = 1)
mutstrsage_common_df = mutstrsage_common_df.reindex(cols, axis = 1)

# %%
# Check column order of each dataframe: 
for col in mutstrsage_common_df.columns:
    print(col)
# Out:
# CHROM
# POS
# ID
# REF
# ALT
# QUAL
# FILTER
# INFO
# FORMAT
# NORMAL
# TUMOR
# t_AF
# n_AF
# t_DP
# n_DP
# t_alt_reads
# n_alt_reads
# t_ref_reads
# n_ref_reads
# VAF
# mut_type
# Caller_intersec
# SAMPLE
# mut

# %%
# Join the list of common mutations again (keep in mind some of them will be repeated!)
final_mutations_df = pd.concat([mutstr_common_df, mutsage_common_df,strsage_common_df,mutstrsage_common_df], ignore_index=True) # ignore index omits the index number of each row in the original table

# Now convert it into a dataframe
final_mutations_df = pd.DataFrame(final_mutations_df) 
print(len(final_mutations_df)) # see that some values are repeated!

# Use drop duplicates to exclude repeated values pandas function drop.duplicates based on 'mut' column
final_mutations_df = final_mutations_df.drop_duplicates(subset=['mut'])
print(len(final_mutations_df))
# Out:
# 80954
# 22125

# %%
final_mutations_df.tail()
# Out:
#        CHROM        POS ID REF ALT QUAL FILTER  \
# 61035  chr18   66559231  .  TA   T  417   PASS
# 61064  chr20   37191658  .   C  CT  317   PASS
# 61073  chr21   19740095  .   G  GA  772   PASS
# 61117   chrX  153193034  .   C  CT  260   PASS
# 61120   chrY   11362309  .  CA   C  287   PASS
#
#                                                     INFO  \
# 61035  LPS=5263;LPS_RC=22;MH=A;RC=AATAAAAAAGCA;RC_IDX...
# 61064  MH=T;RC=TACTTTTTTTTTTTTTTG;RC_IDX=2;RC_LF=TAGT...
# 61073  LPS=5610;LPS_RC=50;MH=A;RC=GGAGAAAAAAAAAAAAAG;...
# 61117  LPS=5871;LPS_RC=14;MH=T;RC=TTCTTTTTTTTTTG;RC_I...
# 61120  MH=A;RC=AACAAAAAAAGT;RC_IDX=2;RC_LF=ATAGCCTACC...
#
#                                                   FORMAT  \
# 61035  GT:ABQ:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:...
# 61064  GT:ABQ:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:...
# 61073  GT:ABQ:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:...
# 61117  GT:ABQ:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:...
# 61120  GT:ABQ:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:...
#
#                                                   NORMAL  ... n_DP  \
# 61035  ./.:0:118,0:0:118:3941,0:126,0:0,0,0,0,0,118,1...  ...  118
# 61064  ./.:33:112,1:0.00885:113:3287,30:119,1:1,0,0,0...  ...  113
# 61073  ./.:0:103,0:0:103:2880,0:118,0:0,0,0,0,0,103,1...  ...  103
# 61117  ./.:0:50,0:0:50:1549,0:51,0:0,0,0,0,0,50,50:0:...  ...   50
# 61120  ./.:0:102,0:0:102:3388,0:112,0:0,0,0,0,0,102,1...  ...  102
#
#        t_alt_reads  n_alt_reads  t_ref_reads  n_ref_reads    VAF  mut_type  \
# 61035           22            0           83          118  0.210     INDEL
# 61064           31            1           89          112  0.254     INDEL
# 61073           52            0           32          103  0.598     INDEL
# 61117           17            0           43           50  0.283     INDEL
# 61120           20            0           78          102  0.202     INDEL
#
#        Caller_intersec        SAMPLE                  mut
# 61035     Strelka_SAGE  sarcoma-lung  chr18_66559231_TA_T
# 61064     Strelka_SAGE  sarcoma-lung  chr20_37191658_C_CT
# 61073     Strelka_SAGE  sarcoma-lung  chr21_19740095_G_GA
# 61117     Strelka_SAGE  sarcoma-lung  chrX_153193034_C_CT
# 61120     Strelka_SAGE  sarcoma-lung   chrY_11362309_CA_C
#
# [5 rows x 24 columns]

# %%
# 1/ First reorder by chromosomes then by position in CHROM and POS columns

# Define a list to order by chromosomes
chrom = ['chr1','chr2','chr3','chr4','chr5','chr6', 'chr7', 'chr8', 'chr9', 'chr10','chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chr23', 'chrX', 'chrY']

# Create a categorical variable for chromosomes
final_mutations_df['CHROM'] = pd.Categorical(final_mutations_df['CHROM'], categories=chrom, ordered=True) # in categories we indicate the order
final_mutations_df = final_mutations_df.sort_values(by=['CHROM','POS']) # it will reorder based on CHROM and POS
final_mutations_df.reset_index(drop=True, inplace=True) # Reset indexes

# %%
final_mutations_df
# Out:
#       CHROM       POS ID REF ALT  QUAL FILTER  \
# 0      chr1    104188  .   C   A     .   PASS
# 1      chr1    843320  .   G   A     .   PASS
# 2      chr1   1118520  .   C   T     .   PASS
# 3      chr1   1136548  .   G   T     .   PASS
# 4      chr1   1182738  .   C   T     .   PASS
# ...     ...       ... ..  ..  ..   ...    ...
# 22120  chrY  26654389  .   A   G   327   PASS
# 22121  chrY  56823266  .   G   A   314   PASS
# 22122  chrY  56842066  .  CT  AC  1241   PASS
# 22123  chrY  56842087  .   T   C     .   PASS
# 22124  chrY  56875391  .   G   A   333   PASS
#
#                                                     INFO  \
# 0      AS_FilterStatus=SITE;AS_SB_TABLE=40,144|18,33;...
# 1      AS_FilterStatus=SITE;AS_SB_TABLE=81,70|44,36;D...
# 2      AS_FilterStatus=SITE;AS_SB_TABLE=114,133|12,30...
# 3      AS_FilterStatus=SITE;AS_SB_TABLE=72,93|44,38;D...
# 4      AS_FilterStatus=SITE;AS_SB_TABLE=126,126|27,25...
# ...                                                  ...
# 22120  RC=GGAGAGGAAT;RC_IDX=6;RC_LF=GTAATGGAGT;RC_NM=...
# 22121  LPS=5879;LPS_RC=16;RC=CAATTTTC;RC_IDX=2;RC_LF=...
# 22122  LPS=5882;LPS_RC=57;RC=ACACACAG;RC_IDX=2;RC_LF=...
# 22123  AS_FilterStatus=SITE;AS_SB_TABLE=213,218|33,30...
# 22124  LPS=5885;LPS_RC=19;RC=GAAGGT;RC_IDX=2;RC_LF=AG...
#
#                                                   FORMAT  \
# 0                GT:AD:AF:DP:F1R2:F2R1:FAD:PGT:PID:PS:SB
# 1                           GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 2                           GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 3                           GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# 4                           GT:AD:AF:DP:F1R2:F2R1:FAD:SB
# ...                                                  ...
# 22120  GT:ABQ:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:...
# 22121  GT:ABQ:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:...
# 22122  GT:ABQ:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:...
# 22123            GT:AD:AF:DP:F1R2:F2R1:FAD:PGT:PID:PS:SB
# 22124  GT:ABQ:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:...
#
#                                                   NORMAL  ... n_DP  \
# 0      0|0:124,0:7.177e-03:124:33,0:29,0:124,0:0|1:10...  ...  124
# 1      0/0:126,0:7.857e-03:126:58,0:63,0:125,0:67,59,0,0  ...  126
# 2      0/0:153,0:6.470e-03:153:62,0:83,0:152,0:78,75,0,0  ...  153
# 3      0/0:123,0:8.107e-03:123:60,0:59,0:121,0:57,66,0,0  ...  123
# 4      0/0:167,0:5.950e-03:167:85,0:68,0:165,0:84,83,0,0  ...  167
# ...                                                  ...  ...  ...
# 22120  ./.:0:57,0:0:58:2084,0:63,0:0,0,0,0,0,57,58:0:...  ...   58
# 22121  ./.:0:460,0:0:460:14466,0:491,0:0,0,0,0,0,460,...  ...  460
# 22122  ./.:0:290,0:0:290:9437,0:306,0:0,0,0,0,0,290,2...  ...  290
# 22123  0|0:295,0:3.303e-03:295:143,0:125,0:295,0:1|0:...  ...  295
# 22124  ./.:0:792,0:0:792:25196,0:817,0:0,0,0,0,0,792,...  ...  792
#
#        t_alt_reads  n_alt_reads  t_ref_reads  n_ref_reads       VAF  mut_type  \
# 0               51            0           60          124  0.459459       SNV
# 1               80            0           25          126  0.761905       SNV
# 2               42            0           94          153  0.308824       SNV
# 3               82            0           42          123  0.661290       SNV
# 4               52            0           85          167  0.379562       SNV
# ...            ...          ...          ...          ...       ...       ...
# 22120           19            0           15           57  0.559000       SNV
# 22121           37            0          398          460  0.085000       SNV
# 22122           66            0          134          290  0.330000       MNV
# 22123           63            0          136          295  0.316583       SNV
# 22124           26            0          677          792  0.037000       SNV
#
#        Caller_intersec        SAMPLE                  mut
# 0       Mutect_Strelka  sarcoma_lung      chr1_104188_C_A
# 1       Mutect_Strelka  sarcoma_lung      chr1_843320_G_A
# 2       Mutect_Strelka  sarcoma_lung     chr1_1118520_C_T
# 3       Mutect_Strelka  sarcoma_lung     chr1_1136548_G_T
# 4       Mutect_Strelka  sarcoma_lung     chr1_1182738_C_T
# ...                ...           ...                  ...
# 22120     Strelka_SAGE  sarcoma-lung    chrY_26654389_A_G
# 22121      Mutect_SAGE  sarcoma-lung    chrY_56823266_G_A
# 22122      Mutect_SAGE  sarcoma-lung  chrY_56842066_CT_AC
# 22123   Mutect_Strelka  sarcoma_lung    chrY_56842087_T_C
# 22124      Mutect_SAGE  sarcoma-lung    chrY_56875391_G_A
#
# [22125 rows x 24 columns]

# %%
# Export table as tsv compressed file
# final_mutations_df.to_csv('/workspace/projects/sjd_melos/MAFs_tables/Lung_List_common_mutations_callers.tsv.gz', sep ='\t', index=None, compression = "gzip")

# %% [markdown]
# ### Histogram VAF common mutations

# %%
# VAF representation through histogram
plt.hist(final_mutations_df['VAF'].tolist(), bins = 200, color = "green")
plt.ylabel('Número de mutaciones', fontsize=16)
plt.xlim([0,1.2]) 
plt.xlabel('VAF', fontsize=16)
plt.title('Sarcoma Metástasis (pulmón)',fontsize=16, weight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.savefig('/workspace/projects/sjd_melos/exports_images/density_vaf_lung_consensus.png',dpi=300,transparent=True, format='png', bbox_inches='tight')
plt.show(final_mutations_df['VAF'].tolist())
